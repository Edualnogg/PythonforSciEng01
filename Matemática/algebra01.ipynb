# %%
import sympy as sp

sp.init_printing()

lista_variaveis = ['x','y']
x,y = sp.symbols(lista_variaveis)

(x+x) + y
# Out:
# 2⋅x + y

# %%
t = x**2 + y**2 + x*y
t
#MAGNÍFICO
# Out:
#  2          2
# x  + x⋅y + y

# %%
#ADICIONANDO VALORES REAIS

resultado = t.subs(x,1).subs(y,2)
resultado
# Out:
# 7
